# %%
import networkx as nx
import matplotlib.pyplot as plt

# Función para generar la plantilla
def grafo_localidades():

    H = nx.Graph()

    # Agregar nodos principales
    H.add_node('Madrugada')
    H.add_node('Mañana')
    H.add_node('Tarde')
    H.add_node('Noche')

    # Agregar nodos de las localidades

    localidades = ['Antonio Nariño', 'Barrios Unidos', 'Bosa', 'Candelaria', 'Chapinero', 'Ciudad Bolivar',
                  'Engativá', 'Kennedy', 'Puente Aranda', 'Rafael Uribe', 'Santa Fe', 'Suba', 'Teusaquillo', 'Tunjuelito', 'Usme']

    for localidad in localidades:
      H.add_node(localidad)


    #Agregar datos

    H.add_edge('Antonio Nariño', 'Madrugada', weight=50)
    H.add_edge('Antonio Nariño', 'Mañana', weight=81)
    H.add_edge('Antonio Nariño', 'Tarde', weight=61)
    H.add_edge('Antonio Nariño', 'Noche', weight=67)

    H.add_edge('Barrios Unidos', 'Madrugada', weight=105)
    H.add_edge('Barrios Unidos', 'Mañana', weight=162)
    H.add_edge('Barrios Unidos', 'Tarde', weight=141)
    H.add_edge('Barrios Unidos', 'Noche', weight=155)

    H.add_edge('Bosa', 'Madrugada', weight=98)
    H.add_edge('Bosa', 'Mañana', weight=96)
    H.add_edge('Bosa', 'Tarde', weight=115)
    H.add_edge('Bosa', 'Noche', weight=82)

    H.add_edge('Candelaria', 'Madrugada', weight=11)
    H.add_edge('Candelaria', 'Mañana', weight=25)
    H.add_edge('Candelaria', 'Tarde', weight=30)
    H.add_edge('Candelaria', 'Noche', weight=11)

    H.add_edge('Chapinero', 'Madrugada', weight=249)
    H.add_edge('Chapinero', 'Mañana', weight=194)
    H.add_edge('Chapinero', 'Tarde', weight=182)
    H.add_edge('Chapinero', 'Noche', weight=198)

    H.add_edge('Ciudad Bolivar', 'Madrugada', weight=73)
    H.add_edge('Ciudad Bolivar', 'Mañana', weight=79)
    H.add_edge('Ciudad Bolivar', 'Tarde', weight=72)
    H.add_edge('Ciudad Bolivar', 'Noche', weight=76)

    H.add_edge('Engativá', 'Madrugada', weight=277)
    H.add_edge('Engativá', 'Mañana', weight=354)
    H.add_edge('Engativá', 'Tarde', weight=261)
    H.add_edge('Engativá', 'Noche', weight=278)

    H.add_edge('Kennedy', 'Madrugada', weight=344)
    H.add_edge('Kennedy', 'Mañana', weight=432)
    H.add_edge('Kennedy', 'Tarde', weight=266)
    H.add_edge('Kennedy', 'Noche', weight=352)

    H.add_edge('Puente Aranda', 'Madrugada', weight=132)
    H.add_edge('Puente Aranda', 'Mañana', weight=180)
    H.add_edge('Puente Aranda', 'Tarde', weight=166)
    H.add_edge('Puente Aranda', 'Noche', weight=128)

    H.add_edge('Rafael Uribe', 'Madrugada', weight=94)
    H.add_edge('Rafael Uribe', 'Mañana', weight=120)
    H.add_edge('Rafael Uribe', 'Tarde', weight=112)
    H.add_edge('Rafael Uribe', 'Noche', weight=103)

    H.add_edge('Santa Fe', 'Madrugada', weight=117)
    H.add_edge('Santa Fe', 'Mañana', weight=173)
    H.add_edge('Santa Fe', 'Tarde', weight=201)
    H.add_edge('Santa Fe', 'Noche', weight=156)

    H.add_edge('Suba', 'Madrugada', weight=298)
    H.add_edge('Suba', 'Mañana', weight=465)
    H.add_edge('Suba', 'Tarde', weight=329)
    H.add_edge('Suba', 'Noche', weight=337)

    H.add_edge('Teusaquillo', 'Madrugada', weight=143)
    H.add_edge('Teusaquillo', 'Mañana', weight=204)
    H.add_edge('Teusaquillo', 'Tarde', weight=218)
    H.add_edge('Teusaquillo', 'Noche', weight=244)

    H.add_edge('Tunjuelito', 'Madrugada', weight=48)
    H.add_edge('Tunjuelito', 'Mañana', weight=48)
    H.add_edge('Tunjuelito', 'Tarde', weight=42)
    H.add_edge('Tunjuelito', 'Noche', weight=54)

    H.add_edge('Usme', 'Madrugada', weight=66)
    H.add_edge('Usme', 'Mañana', weight=62)
    H.add_edge('Usme', 'Tarde', weight=60)
    H.add_edge('Usme', 'Noche', weight=44)

#Imprimir nodos junto al peso de las aristas
    print("Nodos:")
    print(H.nodes())

    print("Aristas:")
    for edge in H.edges:
        print(edge, H.get_edge_data(*edge)['weight'])
    return H

# Obtener el grafo desde la función
G = grafo_localidades()

# Dibujar el grafo con etiquetas de peso en las aristas
pos = nx.spring_layout(G, k=10)  # Ajustamos el valor de k para controlar la separación entre nodos
labels = nx.get_edge_attributes(G, 'weight')
node_size = 500  # Ajustar el tamaño de los nodos
nx.draw_networkx(G, pos, with_labels=True, node_size=node_size, node_color='skyblue', font_size=5, font_weight='normal')
nx.draw_networkx_edges(G, pos, width=[0.05 for u, v in G.edges()], edge_color='black')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels, font_size=8)  # Agregar etiquetas de peso

# Mostrar el grafo
plt.title("Grafo Ponderado de Localidades")
plt.axis('off')  # Ocultar ejes
plt.show()
# Out:
# Nodos:
# ['Madrugada', 'Mañana', 'Tarde', 'Noche', 'Antonio Nariño', 'Barrios Unidos', 'Bosa', 'Candelaria', 'Chapinero', 'Ciudad Bolivar', 'Engativá', 'Kennedy', 'Puente Aranda', 'Rafael Uribe', 'Santa Fe', 'Suba', 'Teusaquillo', 'Tunjuelito', 'Usme']
# Aristas:
# ('Madrugada', 'Antonio Nariño') 50
# ('Madrugada', 'Barrios Unidos') 105
# ('Madrugada', 'Bosa') 98
# ('Madrugada', 'Candelaria') 11
# ('Madrugada', 'Chapinero') 249
# ('Madrugada', 'Ciudad Bolivar') 73
# ('Madrugada', 'Engativá') 277
# ('Madrugada', 'Kennedy') 344
# ('Madrugada', 'Puente Aranda') 132
# ('Madrugada', 'Rafael Uribe') 94
# ('Madrugada', 'Santa Fe') 117
# ('Madrugada', 'Suba') 298
# ('Madrugada', 'Teusaquillo') 143
# ('Madrugada', 'Tunjuelito') 48
# ('Madrugada', 'Usme') 66
# ('Mañana', 'Antonio Nariño') 81
# ('Mañana', 'Barrios Unidos') 162
# ('Mañana', 'Bosa') 96
# ('Mañana', 'Candelaria') 25
# ('Mañana', 'Chapinero') 194
# ('Mañana', 'Ciudad Bolivar') 79
# ('Mañana', 'Engativá') 354
# ('Mañana', 'Kennedy') 432
# ('Mañana', 'Puente Aranda') 180
# ('Mañana', 'Rafael Uribe') 120
# ('Mañana', 'Santa Fe') 173
# ('Mañana', 'Suba') 465
# ('Mañana', 'Teusaquillo') 204
# ('Mañana', 'Tunjuelito') 48
# ('Mañana', 'Usme') 62
# ('Tarde', 'Antonio Nariño') 61
# ('Tarde', 'Barrios Unidos') 141
# ('Tarde', 'Bosa') 115
# ('Tarde', 'Candelaria') 30
# ('Tarde', 'Chapinero') 182
# ('Tarde', 'Ciudad Bolivar') 72
# ('Tarde', 'Engativá') 261
# ('Tarde', 'Kennedy') 266
# ('Tarde', 'Puente Aranda') 166
# ('Tarde', 'Rafael Uribe') 112
# ('Tarde', 'Santa Fe') 201
# ('Tarde', 'Suba') 329
# ('Tarde', 'Teusaquillo') 218
# ('Tarde', 'Tunjuelito') 42
# ('Tarde', 'Usme') 60
# ('Noche', 'Antonio Nariño') 67
# ('Noche', 'Barrios Unidos') 155
# ('Noche', 'Bosa') 82
# ('Noche', 'Candelaria') 11
# ('Noche', 'Chapinero') 198
# ('Noche', 'Ciudad Bolivar') 76
# ('Noche', 'Engativá') 278
# ('Noche', 'Kennedy') 352
# ('Noche', 'Puente Aranda') 128
# ('Noche', 'Rafael Uribe') 103
# ('Noche', 'Santa Fe') 156
# ('Noche', 'Suba') 337
# ('Noche', 'Teusaquillo') 244
# ('Noche', 'Tunjuelito') 54
# ('Noche', 'Usme') 44

# %% [markdown]
# ### ***Algoritmo edge_betweenness_centrality***

# %%
    import networkx as nx

    # Crear un grafo no dirigido y ponderado
    H = nx.Graph()

    # Agregar nodos
    localidades = ['Antonio Nariño', 'Barrios Unidos', 'Bosa', 'Candelaria', 'Chapinero', 'Ciudad Bolivar',
                      'Engativá', 'Kennedy', 'Puente Aranda', 'Rafael Uribe', 'Santa Fe', 'Suba', 'Teusaquillo', 'Tunjuelito', 'Usme']

    for localidad in localidades:
          H.add_node(localidad)

    # Agregar aristas con pesos
    H.add_edge('Antonio Nariño', 'Madrugada', weight=50)
    H.add_edge('Antonio Nariño', 'Mañana', weight=81)
    H.add_edge('Antonio Nariño', 'Tarde', weight=61)
    H.add_edge('Antonio Nariño', 'Noche', weight=67)

    H.add_edge('Barrios Unidos', 'Madrugada', weight=105)
    H.add_edge('Barrios Unidos', 'Mañana', weight=162)
    H.add_edge('Barrios Unidos', 'Tarde', weight=141)
    H.add_edge('Barrios Unidos', 'Noche', weight=155)

    H.add_edge('Bosa', 'Madrugada', weight=98)
    H.add_edge('Bosa', 'Mañana', weight=96)
    H.add_edge('Bosa', 'Tarde', weight=115)
    H.add_edge('Bosa', 'Noche', weight=82)

    H.add_edge('Candelaria', 'Madrugada', weight=11)
    H.add_edge('Candelaria', 'Mañana', weight=25)
    H.add_edge('Candelaria', 'Tarde', weight=30)
    H.add_edge('Candelaria', 'Noche', weight=11)

    H.add_edge('Chapinero', 'Madrugada', weight=249)
    H.add_edge('Chapinero', 'Mañana', weight=194)
    H.add_edge('Chapinero', 'Tarde', weight=182)
    H.add_edge('Chapinero', 'Noche', weight=198)

    H.add_edge('Ciudad Bolivar', 'Madrugada', weight=73)
    H.add_edge('Ciudad Bolivar', 'Mañana', weight=79)
    H.add_edge('Ciudad Bolivar', 'Tarde', weight=72)
    H.add_edge('Ciudad Bolivar', 'Noche', weight=76)

    H.add_edge('Engativá', 'Madrugada', weight=277)
    H.add_edge('Engativá', 'Mañana', weight=354)
    H.add_edge('Engativá', 'Tarde', weight=261)
    H.add_edge('Engativá', 'Noche', weight=278)

    H.add_edge('Kennedy', 'Madrugada', weight=344)
    H.add_edge('Kennedy', 'Mañana', weight=432)
    H.add_edge('Kennedy', 'Tarde', weight=266)
    H.add_edge('Kennedy', 'Noche', weight=352)

    H.add_edge('Puente Aranda', 'Madrugada', weight=132)
    H.add_edge('Puente Aranda', 'Mañana', weight=180)
    H.add_edge('Puente Aranda', 'Tarde', weight=166)
    H.add_edge('Puente Aranda', 'Noche', weight=128)

    H.add_edge('Rafael Uribe', 'Madrugada', weight=94)
    H.add_edge('Rafael Uribe', 'Mañana', weight=120)
    H.add_edge('Rafael Uribe', 'Tarde', weight=112)
    H.add_edge('Rafael Uribe', 'Noche', weight=103)

    H.add_edge('Santa Fe', 'Madrugada', weight=117)
    H.add_edge('Santa Fe', 'Mañana', weight=173)
    H.add_edge('Santa Fe', 'Tarde', weight=201)
    H.add_edge('Santa Fe', 'Noche', weight=156)

    H.add_edge('Suba', 'Madrugada', weight=298)
    H.add_edge('Suba', 'Mañana', weight=465)
    H.add_edge('Suba', 'Tarde', weight=329)
    H.add_edge('Suba', 'Noche', weight=337)

    H.add_edge('Teusaquillo', 'Madrugada', weight=143)
    H.add_edge('Teusaquillo', 'Mañana', weight=204)
    H.add_edge('Teusaquillo', 'Tarde', weight=218)
    H.add_edge('Teusaquillo', 'Noche', weight=244)

    H.add_edge('Tunjuelito', 'Madrugada', weight=48)
    H.add_edge('Tunjuelito', 'Mañana', weight=48)
    H.add_edge('Tunjuelito', 'Tarde', weight=42)
    H.add_edge('Tunjuelito', 'Noche', weight=54)

    H.add_edge('Usme', 'Madrugada', weight=66)
    H.add_edge('Usme', 'Mañana', weight=62)
    H.add_edge('Usme', 'Tarde', weight=60)
    H.add_edge('Usme', 'Noche', weight=44)

    # Calcular la centralidad de intermediación de aristas
    edge_betweenness = nx.edge_betweenness_centrality(H, normalized=False, weight='weight')

    # Imprimir el resultado
    for edge, centrality in edge_betweenness.items():
        print(f'Arista {edge}: Centralidad de Intermediación = {centrality}')
# Out:
# Arista ('Antonio Nariño', 'Madrugada'): Centralidad de Intermediación = 11.0
# Arista ('Antonio Nariño', 'Mañana'): Centralidad de Intermediación = 1.0
# Arista ('Antonio Nariño', 'Tarde'): Centralidad de Intermediación = 4.0
# Arista ('Antonio Nariño', 'Noche'): Centralidad de Intermediación = 2.0
# Arista ('Barrios Unidos', 'Madrugada'): Centralidad de Intermediación = 15.0
# Arista ('Barrios Unidos', 'Mañana'): Centralidad de Intermediación = 0.0
# Arista ('Barrios Unidos', 'Tarde'): Centralidad de Intermediación = 3.0
# Arista ('Barrios Unidos', 'Noche'): Centralidad de Intermediación = 0.0
# Arista ('Bosa', 'Madrugada'): Centralidad de Intermediación = 6.0
# Arista ('Bosa', 'Mañana'): Centralidad de Intermediación = 1.0
# Arista ('Bosa', 'Tarde'): Centralidad de Intermediación = 2.0
# Arista ('Bosa', 'Noche'): Centralidad de Intermediación = 9.0
# Arista ('Candelaria', 'Madrugada'): Centralidad de Intermediación = 32.5
# Arista ('Candelaria', 'Mañana'): Centralidad de Intermediación = 11.0
# Arista ('Candelaria', 'Tarde'): Centralidad de Intermediación = 12.0
# Arista ('Candelaria', 'Noche'): Centralidad de Intermediación = 19.5
# Arista ('Chapinero', 'Madrugada'): Centralidad de Intermediación = 0.0
# Arista ('Chapinero', 'Mañana'): Centralidad de Intermediación = 1.0
# Arista ('Chapinero', 'Tarde'): Centralidad de Intermediación = 9.5
# Arista ('Chapinero', 'Noche'): Centralidad de Intermediación = 7.5
# Arista ('Ciudad Bolivar', 'Madrugada'): Centralidad de Intermediación = 8.0
# Arista ('Ciudad Bolivar', 'Mañana'): Centralidad de Intermediación = 1.0
# Arista ('Ciudad Bolivar', 'Tarde'): Centralidad de Intermediación = 5.0
# Arista ('Ciudad Bolivar', 'Noche'): Centralidad de Intermediación = 4.0
# Arista ('Engativá', 'Madrugada'): Centralidad de Intermediación = 8.0
# Arista ('Engativá', 'Mañana'): Centralidad de Intermediación = 0.0
# Arista ('Engativá', 'Tarde'): Centralidad de Intermediación = 7.0
# Arista ('Engativá', 'Noche'): Centralidad de Intermediación = 3.0
# Arista ('Kennedy', 'Madrugada'): Centralidad de Intermediación = 0.0
# Arista ('Kennedy', 'Mañana'): Centralidad de Intermediación = 0.0
# Arista ('Kennedy', 'Tarde'): Centralidad de Intermediación = 18.0
# Arista ('Kennedy', 'Noche'): Centralidad de Intermediación = 0.0
# Arista ('Puente Aranda', 'Madrugada'): Centralidad de Intermediación = 8.0
# Arista ('Puente Aranda', 'Mañana'): Centralidad de Intermediación = 0.0
# Arista ('Puente Aranda', 'Tarde'): Centralidad de Intermediación = 2.0
# Arista ('Puente Aranda', 'Noche'): Centralidad de Intermediación = 8.0
# Arista ('Rafael Uribe', 'Madrugada'): Centralidad de Intermediación = 11.0
# Arista ('Rafael Uribe', 'Mañana'): Centralidad de Intermediación = 1.0
# Arista ('Rafael Uribe', 'Tarde'): Centralidad de Intermediación = 3.0
# Arista ('Rafael Uribe', 'Noche'): Centralidad de Intermediación = 3.0
# Arista ('Santa Fe', 'Madrugada'): Centralidad de Intermediación = 18.0
# Arista ('Santa Fe', 'Mañana'): Centralidad de Intermediación = 0.0
# Arista ('Santa Fe', 'Tarde'): Centralidad de Intermediación = 0.0
# Arista ('Santa Fe', 'Noche'): Centralidad de Intermediación = 0.0
# Arista ('Suba', 'Madrugada'): Centralidad de Intermediación = 15.0
# Arista ('Suba', 'Mañana'): Centralidad de Intermediación = 0.0
# Arista ('Suba', 'Tarde'): Centralidad de Intermediación = 3.0
# Arista ('Suba', 'Noche'): Centralidad de Intermediación = 0.0
# Arista ('Teusaquillo', 'Madrugada'): Centralidad de Intermediación = 18.0
# Arista ('Teusaquillo', 'Mañana'): Centralidad de Intermediación = 0.0
# Arista ('Teusaquillo', 'Tarde'): Centralidad de Intermediación = 0.0
# Arista ('Teusaquillo', 'Noche'): Centralidad de Intermediación = 0.0
# Arista ('Tunjuelito', 'Madrugada'): Centralidad de Intermediación = 9.0
# Arista ('Tunjuelito', 'Mañana'): Centralidad de Intermediación = 1.0
# Arista ('Tunjuelito', 'Tarde'): Centralidad de Intermediación = 5.0
# Arista ('Tunjuelito', 'Noche'): Centralidad de Intermediación = 3.0
# Arista ('Usme', 'Madrugada'): Centralidad de Intermediación = 2.5
# Arista ('Usme', 'Mañana'): Centralidad de Intermediación = 1.0
# Arista ('Usme', 'Tarde'): Centralidad de Intermediación = 3.5
# Arista ('Usme', 'Noche'): Centralidad de Intermediación = 11.0

# %% [markdown]
# ### ***Algortimo de Louvain Modularity***

# %%
import networkx as nx
from networkx.algorithms import community

def louvain_modularity(G, weight='weight'):
    # Utiliza el algoritmo de Louvain implementado en NetworkX
    communities = community.greedy_modularity_communities(G, weight=weight)
    return list(communities)

# %%
    H = nx.Graph()

    # Agregar nodos principales
    H.add_node('Madrugada')
    H.add_node('Mañana')
    H.add_node('Tarde')
    H.add_node('Noche')

    # Agregar nodos de las localidades

    localidades = ['Antonio Nariño', 'Barrios Unidos', 'Bosa', 'Candelaria', 'Chapinero', 'Ciudad Bolivar',
                  'Engativá', 'Kennedy', 'Puente Aranda', 'Rafael Uribe', 'Santa Fe', 'Suba', 'Teusaquillo', 'Tunjuelito', 'Usme']

    for localidad in localidades:
      H.add_node(localidad)


    #Agregar datos

    H.add_edge('Antonio Nariño', 'Madrugada', weight=50)
    H.add_edge('Antonio Nariño', 'Mañana', weight=81)
    H.add_edge('Antonio Nariño', 'Tarde', weight=61)
    H.add_edge('Antonio Nariño', 'Noche', weight=67)

    H.add_edge('Barrios Unidos', 'Madrugada', weight=105)
    H.add_edge('Barrios Unidos', 'Mañana', weight=162)
    H.add_edge('Barrios Unidos', 'Tarde', weight=141)
    H.add_edge('Barrios Unidos', 'Noche', weight=155)

    H.add_edge('Bosa', 'Madrugada', weight=98)
    H.add_edge('Bosa', 'Mañana', weight=96)
    H.add_edge('Bosa', 'Tarde', weight=115)
    H.add_edge('Bosa', 'Noche', weight=82)

    H.add_edge('Candelaria', 'Madrugada', weight=11)
    H.add_edge('Candelaria', 'Mañana', weight=25)
    H.add_edge('Candelaria', 'Tarde', weight=30)
    H.add_edge('Candelaria', 'Noche', weight=11)

    H.add_edge('Chapinero', 'Madrugada', weight=249)
    H.add_edge('Chapinero', 'Mañana', weight=194)
    H.add_edge('Chapinero', 'Tarde', weight=182)
    H.add_edge('Chapinero', 'Noche', weight=198)

    H.add_edge('Ciudad Bolivar', 'Madrugada', weight=73)
    H.add_edge('Ciudad Bolivar', 'Mañana', weight=79)
    H.add_edge('Ciudad Bolivar', 'Tarde', weight=72)
    H.add_edge('Ciudad Bolivar', 'Noche', weight=76)

    H.add_edge('Engativá', 'Madrugada', weight=277)
    H.add_edge('Engativá', 'Mañana', weight=354)
    H.add_edge('Engativá', 'Tarde', weight=261)
    H.add_edge('Engativá', 'Noche', weight=278)

    H.add_edge('Kennedy', 'Madrugada', weight=344)
    H.add_edge('Kennedy', 'Mañana', weight=432)
    H.add_edge('Kennedy', 'Tarde', weight=266)
    H.add_edge('Kennedy', 'Noche', weight=352)

    H.add_edge('Puente Aranda', 'Madrugada', weight=132)
    H.add_edge('Puente Aranda', 'Mañana', weight=180)
    H.add_edge('Puente Aranda', 'Tarde', weight=166)
    H.add_edge('Puente Aranda', 'Noche', weight=128)

    H.add_edge('Rafael Uribe', 'Madrugada', weight=94)
    H.add_edge('Rafael Uribe', 'Mañana', weight=120)
    H.add_edge('Rafael Uribe', 'Tarde', weight=112)
    H.add_edge('Rafael Uribe', 'Noche', weight=103)

    H.add_edge('Santa Fe', 'Madrugada', weight=117)
    H.add_edge('Santa Fe', 'Mañana', weight=173)
    H.add_edge('Santa Fe', 'Tarde', weight=201)
    H.add_edge('Santa Fe', 'Noche', weight=156)

    H.add_edge('Suba', 'Madrugada', weight=298)
    H.add_edge('Suba', 'Mañana', weight=465)
    H.add_edge('Suba', 'Tarde', weight=329)
    H.add_edge('Suba', 'Noche', weight=337)

    H.add_edge('Teusaquillo', 'Madrugada', weight=143)
    H.add_edge('Teusaquillo', 'Mañana', weight=204)
    H.add_edge('Teusaquillo', 'Tarde', weight=218)
    H.add_edge('Teusaquillo', 'Noche', weight=244)

    H.add_edge('Tunjuelito', 'Madrugada', weight=48)
    H.add_edge('Tunjuelito', 'Mañana', weight=48)
    H.add_edge('Tunjuelito', 'Tarde', weight=42)
    H.add_edge('Tunjuelito', 'Noche', weight=54)

    H.add_edge('Usme', 'Madrugada', weight=66)
    H.add_edge('Usme', 'Mañana', weight=62)
    H.add_edge('Usme', 'Tarde', weight=60)
    H.add_edge('Usme', 'Noche', weight=44)



    # Ejecuta Louvain
    communities = louvain_modularity(H, weight='weight')

    # Imprime comunidades
    for c in communities:
        print(list(c))
# Out:
# ['Candelaria', 'Puente Aranda', 'Santa Fe', 'Rafael Uribe', 'Tarde', 'Bosa']
# ['Antonio Nariño', 'Teusaquillo', 'Barrios Unidos', 'Ciudad Bolivar', 'Tunjuelito', 'Noche']
# ['Chapinero', 'Usme', 'Madrugada', 'Kennedy']
# ['Mañana', 'Suba', 'Engativá']
